# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Para ejercitarte y afianzar lo aprendido sobre conceptos básicos de Matplotlib, completa los siguientes ejercicios. Recuerda que necesitarás datos que están en el directorio data que acompaña al notebook (búscalo en el repositorio de ejercicios)
#
# La solución a los mismos las tienes ya, intenta no mirarlos de primeras pero no dejes de hacerlo cuando hayas terminado por si te pudieran aportar.

# %%
pip install squarify
# Out:
# Collecting squarify
#   Downloading squarify-0.4.3-py3-none-any.whl.metadata (540 bytes)
# Downloading squarify-0.4.3-py3-none-any.whl (4.3 kB)
# Installing collected packages: squarify
# Successfully installed squarify-0.4.3
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install folium
# Out:
# Note: you may need to restart the kernel to use updated packages.Collecting folium
#   Downloading folium-0.17.0-py2.py3-none-any.whl.metadata (3.8 kB)
# Collecting branca>=0.6.0 (from folium)
#   Downloading branca-0.7.2-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: jinja2>=2.9 in c:\users\sorim\appdata\local\programs\python\python312\lib\site-packages (from folium) (3.1.4)
# Requirement already satisfied: numpy in c:\users\sorim\appdata\local\programs\python\python312\lib\site-packages (from folium) (1.26.4)
# Requirement already satisfied: requests in c:\users\sorim\appdata\local\programs\python\python312\lib\site-packages (from folium) (2.32.2)
# Collecting xyzservices (from folium)
#   Downloading xyzservices-2024.6.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sorim\appdata\local\programs\python\python312\lib\site-packages (from jinja2>=2.9->folium) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sorim\appdata\local\programs\python\python312\lib\site-packages (from requests->folium) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sorim\appdata\local\programs\python\python312\lib\site-packages (from requests->folium) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sorim\appdata\local\programs\python\python312\lib\site-packages (from requests->folium) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sorim\appdata\local\programs\python\python312\lib\site-packages (from requests->folium) (2024.2.2)
# Downloading folium-0.17.0-py2.py3-none-any.whl (108 kB)
#    ---------------------------------------- 0.0/108.4 kB ? eta -:--:--
#    -------------- ------------------------ 41.0/108.4 kB 991.0 kB/s eta 0:00:01
#    ---------------------------------------- 108.4/108.4 kB 1.6 MB/s eta 0:00:00
# Downloading branca-0.7.2-py3-none-any.whl (25 kB)
# Downloading xyzservices-2024.6.0-py3-none-any.whl (83 kB)
#    ---------------------------------------- 0.0/83.9 kB ? eta -:--:--
#    ---------------------------------------- 83.9/83.9 kB 4.9 MB/s eta 0:00:00
# Installing collected packages: xyzservices, branca, folium
# Successfully installed branca-0.7.2 folium-0.17.0 xyzservices-2024.6.0
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install plotly
# Out:
# Requirement already satisfied: plotly in c:\users\sorim\appdata\local\programs\python\python312\lib\site-packages (5.22.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\sorim\appdata\local\programs\python\python312\lib\site-packages (from plotly) (8.5.0)
# Requirement already satisfied: packaging in c:\users\sorim\appdata\local\programs\python\python312\lib\site-packages (from plotly) (24.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ### Ejercicio 0

# %% [markdown]
# Importa los paquetes y módulos que necesites a lo largo del notebook

# %%
import matplotlib.pyplot as plt
plt.style.use("seaborn-v0_8-white")
import numpy as np

# %% [markdown]
# ### Ejercicio 1
#
# Construye la siguiente figura con dos subplots utilizando el estilo MATLAB (es decir plt.\<funcion\>, no usando objetos `Axes`)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
fig = plt.figure()
x = np.linspace(0,10,100)

plt.subplot(1, 2, 1)
plt.plot(x, np.sin(x))
plt.xlim(0,10)
plt.ylim(-1, 1)
plt.title("Seno")

plt.subplot(1,2,2)
plt.plot(x, np.cos(x))
plt.xlim(0,10)
plt.ylim(-1, 1)
plt.title("Coseno");

# %% [markdown]
# ### Ejercicio 2
#
# Reproduce la imagen de la figura usando tres subplots en una columna, utilizando objetos `Axes`. Las dos primeras son las funciones anteriores y la tercera es la tangente (np.tan)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
fig = plt.figure()

fig, ax = plt.subplots(3,1)
fig.subplots_adjust(hspace = 0.4, wspace = 1)

ax[0].set_xlim(0,10)
ax[0].set_ylim(-1, 1)
ax[0].plot(x, np.sin(x))

ax[1].set_xlim(0,10)
ax[1].set_ylim(-1, 1)
ax[1].plot(x, np.cos(x))

ax[2].set_xlim(0,10)
ax[2].set_ylim(-40, 20)
ax[2].plot(x, np.tan(x));

# %% [markdown]
# ### Ejercicio 3: Ajuste de Colores y Estilos de Línea
#
# Modifica la primera figura para que se muestre de la siguiente manera

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
fig = plt.figure()
x = np.linspace(0,10,100)

plt.subplot(1, 2, 1)
plt.plot(x, np.sin(x), '--m')
plt.xlim(0,10)
plt.ylim(-1, 1)

plt.subplot(1,2,2)
plt.plot(x, np.cos(x), '-.c')
plt.xlim(0,10)
plt.ylim(-1, 1)
# Out:
# (-1.0, 1.0)

# %% [markdown]
# ### Ejercicio 4
#
# Reproduce la figura siguiente. Recuerda que las funciones seno hiperbólico y coseno hiperbólico se obtienen así:
# * np.sinh, seno hiperbólico;
# * np.cosh, coseno hiperbólico;

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
fig = plt.figure()
fig.subplots_adjust(hspace = 0.5)


plt.subplot(2, 1, 1)
plt.plot(x, np.sinh(x))
plt.xlim(0,10)
plt.ylim(0, 10000)
plt.title("Seno Hiperbólico")
plt.xlabel("x")
plt.ylabel("sinh(x)")

plt.subplot(2,1,2)
plt.plot(x, np.cosh(x))
plt.xlim(0,10)
plt.ylim(0, 10000)
plt.title("Coseno hiperbólico")
plt.xlabel("x")
plt.ylabel("cosh(x)")
# Out:
# Text(0, 0.5, 'cosh(x)')

# %% [markdown]
# ### Ejercicio 5: Ajustando el Espaciado de Subplots
#
# Reproduce la siguiente figura con cuatro subplots, ajusta el espaciado entre los subplots para evitar la superosición (tal y como ves en la figura), emplea `subplots_adjust` y los parámetros hspace y wspace.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
fig = plt.figure()
fig.subplots_adjust(hspace = 0.5, wspace = 0.5)


plt.subplot(2, 2, 1)
plt.plot(x, np.sin(x))
plt.xlim(0,10)
plt.ylim(-1, 1)

plt.subplot(2,2,2)
plt.plot(x, np.cos(x))
plt.xlim(0,10)
plt.ylim(-1, 1)

plt.subplot(2,2,3)
plt.plot(x, np.tan(x))
plt.xlim(0,10)
plt.ylim(-40, 20)

plt.subplot(2,2,4)
plt.plot(x, np.sqrt(x))
plt.xlim(0,10)
plt.ylim(0, 4)
# Out:
# (0.0, 4.0)

# %% [markdown]
# ### Ejercicio 6:
#
# Reproduce la figura siguiente empleando sólo el estilo MATLAB (plt.\<funcion>\) y creando solo el contenido de los dos primeros gráficos (fila 1). Luego usa el estilo con métodos (objetos `axes`) para añadir el tercer gráfico.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
fig = plt.figure()
fig, ax = plt.subplots(2,1)

ax[0].set_xlim(0,10)
ax[0].set_ylim(-1,3)
ax[0].plot(x, np.cos(x), label = "Coseno")
ax[0].plot(x, np.sqrt(x), label = "raiz cuadrada")
ax[0].legend()
ax[0].set_title("Raíz Cuadrada y coseno")

ax[1].set_xlim(0,10)
ax[1].set_ylim(-1,1)
ax[1].plot(x, np.sin(x))
ax[1].set_title("Seno");

# %% [markdown]
# ### Ejercicio 7
#
# Para terminar, reproduce la imagen de la figura

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
fig = plt.figure()

plt.plot(x, np.sin(x), 'o', mfc='yellow', mec='blue', ms = 10, mew = 2)

# mfc es el color del relleno
# mec el color del borde
# ms tamaño de los marcadores
# mew tamaño del borde
